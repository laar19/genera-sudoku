# %%
#!pip install deap

# %% [markdown]
# ## Librerías

# %%
import random                         # Se utiliza para generar números aleatorios
import numpy as np                    # Se utiliza para provechar sus funciones matemáticas
import matplotlib.pyplot as plt       # Se utiliza para graficar
from deap import base, creator, tools # Framework

# %% [markdown]
# ## Funciones

# %% [markdown]
# ### Función para imprimir un sudoku

# %%
# Recibe como parámetro una lista con 81 elementos
def imprime_sudoku(sudoku):
    x = 0 # Equivale al rango de...
    y = 3 # los 3 primeros valores del sudoku

    iteracion = 0
    while iteracion < 9: # Los primeros 9 valores conforman la primera fila
        if iteracion == 3 or iteracion == 6:
            print("----- + ----- + -----")

        for i in range(x, y):
            print(sudoku[i], end=" ")
        print("| ", end="")
        x += 3
        y += 3

        for i in range(x, y):
            print(sudoku[i], end=" ")
        print("| ", end="")
        x += 3
        y += 3

        for i in range(x, y):
            print(sudoku[i], end=" ")
        print()
        x += 3
        y += 3

        iteracion += 1

# %% [markdown]
# ### Función fitness

# %%
# Retorna el fitness de un sudoku dado, recibe como parámetro una lista con 81 elementos
def calcula_fitness(sudoku):
    # Retorna la cantidad de números repetidos en una fila, columna o sector, recibe como parámetro una lista con 81 elementos
    def repetidos(aux):
        fit = 0                            # Fitness
        if len(aux) != len(set(aux)):      # Si el tamaño de la fila, columna o sector (con todos los valores, incluyendo los repetidos) es distindo
                                           # al tamaño sin incluir los valores repetidos...
            fit = len(aux) - len(set(aux)) # Fitness toma el valor del resultado de la diferencia
        return fit

    # Recorre las filas o las columnas del sudoku, recibe como parámetros una lista con 81 elementos que representa el sudoku entero, una lista
    # con 9 elementos que representa la primera fila o columna del sudoku, y un valor entero que representa el desplazamiento, que depende si el
    # parámetro anterior es una fila o una columna
    def evalua_filas_o_columnas(sudoku, fil_col, desplazamiento):
        iteracion = 0
        fit = 0 # Fitness
        while iteracion < 9: # 9 columnas o filas
            aux = list() # Lista auxiliar

            # Cada elemento del sudoku en la columna o fila se añade a una lista auxiliar
            for i in fil_col:
                aux.append(sudoku[i])

            # Se calcula el fitness de la columna o fila (representada en la lista auxiliar)
            fit += repetidos(aux) # Se incrementa el valor actual del fitness con el resultado devuelo

            # Desplazamiento para evaluar la siguiente columna o fila
            for i in range(0, len(fil_col)):
                fil_col[i] += desplazamiento

            iteracion += 1
        return fit

    # Retorna, iterativamente, cada uno de los sectores del sudoku, recibe como parámetros una lista de 81 elementos que representa el sudoku...
    # y un número entero que representa la posición del primer elemento ubicado en la esquina superior izquierda del sector
    def recorre_sectores(sudoku, posicion):
        # Posiciones del primer sector ubicado en la esquina superior izquierda
        sector = [
            sudoku[posicion+0+0],  sudoku[posicion+1+0],  sudoku[posicion+2+0],
            sudoku[posicion+0+9],  sudoku[posicion+1+9],  sudoku[posicion+2+9],
            sudoku[posicion+0+18], sudoku[posicion+1+18], sudoku[posicion+2+18]
        ]
        return sector
    
    fitness  = 0 # Fitness global
    columnas = [0, 9, 18, 27, 36, 45, 54, 63, 72] # Posiciones de la primera columna de izquierda a derecha
    filas    = [0, 1, 2, 3, 4, 5, 6, 7, 8]        # Posiciones de la primera fila de arriba hacia abajo
    
    # Evalúa las columnas
    fitness += evalua_filas_o_columnas(sudoku, columnas, 1)
        
    # Evalúa las filas
    fitness += evalua_filas_o_columnas(sudoku, filas, 9)
        
    # Evalúa los sectores
    posiciones_sectores = [0, 3, 6, 27, 30, 33, 54, 57, 60] # Posiciones del primer elemento (esquina superior izquierda) de cada sector
    for i in posiciones_sectores:
        aux = recorre_sectores(sudoku, i) # Obtiene el sector dado su primer elemento (esquina superior izquierda)
        fitness += repetidos(aux)         # Calcula e incrementa el fitness

    return (float(fitness),)

# %% [markdown]
# ### Función de mutación, copiada del libro Clinton Sheppard - Genetic Algorithms with Python (2016)

# %%
def shuffle_in_place(genes, first, last):
    while first < last:
        index = random.randint(first, last)
        genes[first], genes[index] = genes[index], genes[first]
        first += 1

def index_row(index):
    return int(index / 9)

def index_column(index):
    return int(index % 9)

def row_column_section(row, column):
    return int(row / 3) * 3 + int(column / 3)

def section_start(index):
    return int((index_row(index) % 9) / 3) * 27 + int(
        index_column(index) / 3) * 3

def build_validation_rules():
    rules = []
    for index in range(80):
        itsRow = index_row(index)
        itsColumn = index_column(index)
        itsSection = row_column_section(itsRow, itsColumn)

        for index2 in range(index + 1, 81):
            otherRow = index_row(index2)
            otherColumn = index_column(index2)
            otherSection = row_column_section(otherRow, otherColumn)
            if itsRow == otherRow or \
                            itsColumn == otherColumn or \
                            itsSection == otherSection:
                rules.append(Rule(index, index2))

    rules.sort(key=lambda x: x.OtherIndex * 100 + x.Index)
    return rules

class Rule:
    def __init__(self, it, other):
        if it > other:
            it, other = other, it
        self.Index = it
        self.OtherIndex = other

    def __eq__(self, other):
        return self.Index == other.Index and \
               self.OtherIndex == other.OtherIndex

    def __hash__(self):
        return self.Index * 100 + self.OtherIndex

validationRules = build_validation_rules()

def mutate(genes, validationRules):
    selectedRule = next(rule for rule in validationRules
                        if genes[rule.Index] == genes[rule.OtherIndex])
        
    if selectedRule is None:
        return

    if index_row(selectedRule.OtherIndex) % 3 == 2 \
            and random.randint(0, 10) == 0:
        sectionStart = section_start(selectedRule.Index)
        current = selectedRule.OtherIndex
        while selectedRule.OtherIndex == current:
            shuffle_in_place(genes, sectionStart, 80)
            selectedRule = next(rule for rule in validationRules
                                if genes[rule.Index] == genes[rule.OtherIndex])
        return

    row = index_row(selectedRule.OtherIndex)
    start = row * 9
    indexA = selectedRule.OtherIndex
    indexB = random.randrange(start, len(genes))
    genes[indexA], genes[indexB] = genes[indexB], genes[indexA]

# %% [markdown]
# ## Configuración del framework

# %%
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))    # Se crea la clase "FitnessMin", derivada de la clase "base.Fitness"
creator.create("Individual", list, fitness=creator.FitnessMin) # Se crea la clase Individual, representada en el tipo de dato "lista"

# Se instancia el objeto toolbox de la clase "base.Toolbox()". Este objeto contiene el método "register" que se usará a continuación
toolbox = base.Toolbox()

# Se registra la función fitness
toolbox.register("evaluate", calcula_fitness)

TAMANIO_INDIVIDUO = 81 # Tamaño de cada individuo (sudokus aleatorios generados)

# "toolbox.register"() añade un método al objeto "toolbox". Este método es denominado "entero_aleatorio" y llama a la función...
#  "random.randint" generando un número aleatorio entre 1 y 9 (los valores válidos del sudoku)
toolbox.register("entero_aleatorio", random.randint, 1, 9)

# Este método genera un nuevo individuo
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.entero_aleatorio, n=TAMANIO_INDIVIDUO)

# Este método genera una nueva población, llamando al método que genera individuos
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Operador de cruce. Registra el método para el cruce en 2 puntos
toolbox.register("mate", tools.cxTwoPoint)

# Operador de Selección. El método de selección es por "torneo", tomando como criterio de selección el fitness
toolbox.register("select", tools.selTournament, tournsize=3, fit_attr="fitness")

# %% [markdown]
# ## Dinámica evolutiva, copiada del ejemplo "One Max Problem" de la documentación del framework DEAP

# %%
def dinamica_evolutiva(estadisticas):
    # Función que retorna un diccionario con la media, estándar, máximo y mínimo fitness de cada iteración
    def add_estadisticas(poblacion, iteracion=1):
        fitnesses = [individual.fitness.values[0] for individual in poblacion]
        return {
            "ite" :  iteracion,
            "mean":  np.mean(fitnesses),
            "std" :  np.std(fitnesses),
            "max" :  np.max(fitnesses),
            "min" :  np.min(fitnesses)
        }

    # create an initial population of 400 individuals (where
    # each individual is a list of integers)
    pop = toolbox.population(n=400)

    # CXPB  is the probability with which two individuals
    #       are crossed
    #
    # MUTPB is the probability for mutating an individual
    CXPB, MUTPB = 0.83, 0.75
    
    print("Start of evolution")
    
    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit
    
    print("  Evaluated %i individuals" % len(pop))

    # Extracting all the fitnesses of 
    fits = [ind.fitness.values[0] for ind in pop]

    # Variable keeping track of the number of generations
    g = 0
    
    # Begin the evolution
    while min(fits) > 0 and g < 300:
        # A new generation
        g = g + 1
        print("-- Generation %i --" % g)
        
        # Select the next generation individuals
        offspring = toolbox.select(pop, len(pop))
        # Clone the selected individuals
        offspring = list(map(toolbox.clone, offspring))
    
        # Apply crossover and mutation on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):

            # cross two individuals with probability CXPB
            if random.random() < CXPB:
                toolbox.mate(child1, child2)

                # fitness values of the children
                # must be recalculated later
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:

            # mutate an individual with probability MUTPB
            if random.random() < MUTPB:
                mutate(mutant, validationRules)
                del mutant.fitness.values
    
        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        
        print("  Evaluated %i individuals" % len(invalid_ind))
        
        # The population is entirely replaced by the offspring
        pop[:] = offspring

        # Se generan las estadísticas
        estadisticas.append(add_estadisticas(pop, g))
        
        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in pop]
        
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        
        print("  Min %s" % min(fits))
        print("  Max %s" % max(fits))
        print("  Avg %s" % mean)
        print("  Std %s" % std)

    best_ind = tools.selBest(pop, 1)[0]

    return {
        "best_ind" :  best_ind,
        "g"        :  g
    }

# %% [markdown]
# ## Función principal

# %%
def main(estadisticas):
    try:
        resultado = dinamica_evolutiva(estadisticas)
        if resultado["best_ind"].fitness.values[0] != 0.0:
            main(estadisticas)
        else:
            print("\n\nSOLUCIÓN en la generación {}".format(resultado["g"]))
            imprime_sudoku(resultado["best_ind"])
            print("Fitness: {}".format(resultado["best_ind"].fitness.values[0]))
    except:
        main(estadisticas)

# %% [markdown]
# ## Gráfica

# %%
# Se crea un diagrama de dispersión
def grafica(estadisticas):
    plt.scatter(range(1, len(estadisticas)+1), [s["mean"] for s in estadisticas], marker=".")
    plt.title("Promedio de fitness por iteración")
    plt.xlabel("Iteraciones")
    plt.ylabel("Fitness")
    plt.show()

# %% [markdown]
# ## Main

# %%
# %%time
estadisticas = list()
main(estadisticas)
# Out:
# Start of evolution
#   Evaluated 400 individuals
# -- Generation 1 --
#   Evaluated 384 individuals
#   Min 65.0
#   Max 95.0
#   Avg 80.19
#   Std 4.881997541990424
# -- Generation 2 --
#   Evaluated 384 individuals
#   Min 65.0
#   Max 91.0
#   Avg 76.975
#   Std 4.585234454201974
# -- Generation 3 --
#   Evaluated 380 individuals
#   Min 64.0
#   Max 87.0
#   Avg 74.65
#   Std 4.47465082436608
# -- Generation 4 --
#   Evaluated 382 individuals
#   Min 57.0
#   Max 86.0
#   Avg 72.72
#   Std 4.532835757006829
# -- Generation 5 --
#   Evaluated 385 individuals
#   Min 55.0
#   Max 88.0
#   Avg 71.6375
#   Std 4.76823801314478
# -- Generation 6 --
#   Evaluated 380 individuals
#   Min 53.0
#   Max 82.0
#   Avg 69.58
#   Std 5.116014073475569
# -- Generation 7 --
#   Evaluated 385 individuals
#   Min 54.0
#   Max 83.0
#   Avg 68.2275
#   Std 5.067123814354562
# -- Generation 8 --
#   Evaluated 384 individuals
#   Min 54.0
#   Max 84.0
#   Avg 66.785
#   Std 5.183027590125362
# -- Generation 9 --
#   Evaluated 386 individuals
#   Min 54.0
#   Max 80.0
#   Avg 65.51
#   Std 4.981957446626728
# -- Generation 10 --
#   Evaluated 377 individuals
#   Min 52.0
#   Max 83.0
#   Avg 64.28
#   Std 5.223657722324411
# -- Generation 11 --
#   Evaluated 385 individuals
#   Min 51.0
#   Max 83.0
#   Avg 63.0075
#   Std 4.905858105367471
# -- Generation 12 --
#   Evaluated 384 individuals
#   Min 50.0
#   Max 90.0
#   Avg 62.1625
#   Std 5.633479719498401
# -- Generation 13 --
#   Evaluated 376 individuals
#   Min 47.0
#   Max 87.0
#   Avg 60.915
#   Std 5.338799022252095
# -- Generation 14 --
#   Evaluated 381 individuals
#   Min 46.0
#   Max 83.0
#   Avg 59.745
#   Std 5.271145511176909
# -- Generation 15 --
#   Evaluated 386 individuals
#   Min 44.0
#   Max 88.0
#   Avg 59.1325
#   Std 5.895332369765059
# -- Generation 16 --
#   Evaluated 384 individuals
#   Min 46.0
#   Max 97.0
#   Avg 58.9375
#   Std 6.269257830875987
# -- Generation 17 --
#   Evaluated 381 individuals
#   Min 43.0
#   Max 86.0
#   Avg 58.1
#   Std 6.217716622683914
# -- Generation 18 --
#   Evaluated 387 individuals
#   Min 43.0
#   Max 89.0
#   Avg 56.8625
#   Std 7.094264849158117
# -- Generation 19 --
#   Evaluated 386 individuals
#   Min 42.0
#   Max 93.0
#   Avg 55.2225
#   Std 6.247238890101767
# -- Generation 20 --
#   Evaluated 386 individuals
#   Min 41.0
#   Max 95.0
#   Avg 55.2075
#   Std 8.299665279395292
# -- Generation 21 --
#   Evaluated 385 individuals
#   Min 39.0
#   Max 91.0
#   Avg 53.69
#   Std 7.7465411636420205
# -- Generation 22 --
#   Evaluated 382 individuals
#   Min 37.0
#   Max 91.0
#   Avg 51.7
#   Std 7.507329751649362
# -- Generation 23 --
#   Evaluated 387 individuals
#   Min 37.0
#   Max 92.0
#   Avg 50.1025
#   Std 7.756093975062468
# -- Generation 24 --
#   Evaluated 389 individuals
#   Min 37.0
#   Max 88.0
#   Avg 48.24
#   Std 5.982674986993679
# -- Generation 25 --
#   Evaluated 378 individuals
#   Min 37.0
#   Max 93.0
#   Avg 47.4125
#   Std 7.105092803756998
# -- Generation 26 --
#   Evaluated 387 individuals
#   Min 36.0
#   Max 88.0
#   Avg 45.925
#   Std 6.237337172223459
# -- Generation 27 --
#   Evaluated 382 individuals
#   Min 30.0
#   Max 90.0
#   Avg 44.4775
#   Std 5.722280467610808
# -- Generation 28 --
#   Evaluated 376 individuals
#   Min 30.0
#   Max 94.0
#   Avg 42.92
#   Std 5.060988045826615
# -- Generation 29 --
#   Evaluated 385 individuals
#   Min 30.0
#   Max 51.0
#   Avg 41.245
#   Std 3.1599011060475144
# -- Generation 30 --
#   Evaluated 383 individuals
#   Min 30.0
#   Max 81.0
#   Avg 40.325
#   Std 4.331786582923926
# -- Generation 31 --
#   Evaluated 388 individuals
#   Min 30.0
#   Max 85.0
#   Avg 39.2725
#   Std 4.612292678267489
# -- Generation 32 --
#   Evaluated 377 individuals
#   Min 28.0
#   Max 73.0
#   Avg 37.7125
#   Std 3.782174473765048
# -- Generation 33 --
#   Evaluated 382 individuals
#   Min 28.0
#   Max 91.0
#   Avg 36.9625
#   Std 6.0540146803588275
# -- Generation 34 --
#   Evaluated 379 individuals
#   Min 26.0
#   Max 82.0
#   Avg 35.6975
#   Std 4.979055507824762
# -- Generation 35 --
#   Evaluated 382 individuals
#   Min 26.0
#   Max 44.0
#   Avg 34.185
#   Std 3.001795296151911
# -- Generation 36 --
#   Evaluated 393 individuals
#   Min 24.0
#   Max 80.0
#   Avg 33.7
#   Std 4.342810150121655
# -- Generation 37 --
#   Evaluated 378 individuals
#   Min 26.0
#   Max 78.0
#   Avg 32.6675
#   Std 3.990857520633904
# -- Generation 38 --
#   Evaluated 378 individuals
#   Min 24.0
#   Max 41.0
#   Avg 31.885
#   Std 2.7643760598008256
# -- Generation 39 --
#   Evaluated 383 individuals
#   Min 23.0
#   Max 65.0
#   Avg 31.27
#   Std 3.1673490492839615
# -- Generation 40 --
#   Evaluated 383 individuals
#   Min 21.0
#   Max 66.0
#   Avg 30.52
#   Std 3.820942292157803
# -- Generation 41 --
#   Evaluated 381 individuals
#   Min 20.0
#   Max 82.0
#   Avg 30.155
#   Std 5.678113683257842
# -- Generation 42 --
#   Evaluated 385 individuals
#   Min 20.0
#   Max 90.0
#   Avg 29.6675
#   Std 7.027584488997625
# -- Generation 43 --
#   Evaluated 383 individuals
#   Min 21.0
#   Max 86.0
#   Avg 29.03
#   Std 8.481986795556802
# -- Generation 44 --
#   Evaluated 388 individuals
#   Min 19.0
#   Max 84.0
#   Avg 27.8925
#   Std 7.687063402236258
# -- Generation 45 --
#   Evaluated 384 individuals
#   Min 19.0
#   Max 83.0
#   Avg 28.09
#   Std 10.176782399167235
# -- Generation 46 --
#   Evaluated 387 individuals
#   Min 18.0
#   Max 90.0
#   Avg 27.13
#   Std 10.397744947824025
# -- Generation 47 --
#   Evaluated 377 individuals
#   Min 17.0
#   Max 86.0
#   Avg 26.255
#   Std 9.641056736686078
# -- Generation 48 --
#   Evaluated 389 individuals
#   Min 17.0
#   Max 86.0
#   Avg 26.785
#   Std 11.526221193435424
# -- Generation 49 --
#   Evaluated 376 individuals
#   Min 17.0
#   Max 89.0
#   Avg 26.345
#   Std 11.500911920365278
# -- Generation 50 --
#   Evaluated 383 individuals
#   Min 17.0
#   Max 87.0
#   Avg 26.035
#   Std 12.023675602743113
# -- Generation 51 --
#   Evaluated 379 individuals
#   Min 17.0
#   Max 86.0
#   Avg 24.605
#   Std 10.117014134615015
# -- Generation 52 --
#   Evaluated 380 individuals
#   Min 15.0
#   Max 87.0
#   Avg 24.0825
#   Std 10.838620472643186
# -- Generation 53 --
#   Evaluated 384 individuals
#   Min 14.0
#   Max 92.0
#   Avg 24.5825
#   Std 12.661287207468282
# -- Generation 54 --
#   Evaluated 380 individuals
#   Min 13.0
#   Max 84.0
#   Avg 22.5
#   Std 10.339245620450265
# -- Generation 55 --
#   Evaluated 390 individuals
#   Min 14.0
#   Max 86.0
#   Avg 22.055
#   Std 10.934439857624167
# -- Generation 56 --
#   Evaluated 385 individuals
#   Min 12.0
#   Max 91.0
#   Avg 19.5975
#   Std 8.094781884028745
# -- Generation 57 --
#   Evaluated 384 individuals
#   Min 12.0
#   Max 74.0
#   Avg 18.125
#   Std 5.184050057628687
# -- Generation 58 --
#   Evaluated 382 individuals
#   Min 11.0
#   Max 74.0
#   Avg 17.315
#   Std 5.665313318784756
# -- Generation 59 --
#   Evaluated 384 individuals
#   Min 9.0
#   Max 61.0
#   Avg 16.245
#   Std 3.187471568500647
# -- Generation 60 --
#   Evaluated 381 individuals
#   Min 9.0
#   Max 23.0
#   Avg 15.64
#   Std 2.2159422375143225
# -- Generation 61 --
#   Evaluated 382 individuals
#   Min 9.0
#   Max 23.0
#   Avg 15.2725
#   Std 2.1291415523632917
# -- Generation 62 --
#   Evaluated 382 individuals
#   Min 9.0
#   Max 22.0
#   Avg 14.955
#   Std 2.2040814413265184
# -- Generation 63 --
#   Evaluated 388 individuals
#   Min 8.0
#   Max 21.0
#   Avg 14.64
#   Std 2.2727516362330435
# -- Generation 64 --
#   Evaluated 380 individuals
#   Min 8.0
#   Max 21.0
#   Avg 14.3125
#   Std 2.307562296017166
# -- Generation 65 --
#   Evaluated 377 individuals
#   Min 9.0
#   Max 22.0
#   Avg 14.0575
#   Std 2.4472829321514964
# -- Generation 66 --
#   Evaluated 380 individuals
#   Min 7.0
#   Max 23.0
#   Avg 13.9175
#   Std 2.5299592388020775
# -- Generation 67 --
#   Evaluated 389 individuals
#   Min 7.0
#   Max 20.0
#   Avg 13.4525
#   Std 2.2288435902951966
# -- Generation 68 --
#   Evaluated 378 individuals
#   Min 8.0
#   Max 21.0
#   Avg 13.3275
#   Std 2.4280123043345543
# -- Generation 69 --
#   Evaluated 384 individuals
#   Min 8.0
#   Max 23.0
#   Avg 13.035
#   Std 2.4070261735178557
# -- Generation 70 --
#   Evaluated 376 individuals
#   Min 8.0
#   Max 22.0
#   Avg 12.88
#   Std 2.4951152278001083
# -- Generation 71 --
#   Evaluated 385 individuals
#   Min 6.0
#   Max 20.0
#   Avg 12.64
#   Std 2.3022597594537344
# -- Generation 72 --
#   Evaluated 385 individuals
#   Min 6.0
#   Max 20.0
#   Avg 12.2075
#   Std 2.3842071533321123
# -- Generation 73 --
#   Evaluated 388 individuals
#   Min 5.0
#   Max 21.0
#   Avg 11.9925
#   Std 2.5529284655078004
# -- Generation 74 --
#   Evaluated 377 individuals
#   Min 4.0
#   Max 79.0
#   Avg 11.935
#   Std 4.241553371112992
# -- Generation 75 --
#   Evaluated 376 individuals
#   Min 3.0
#   Max 64.0
#   Avg 11.54
#   Std 4.776337509012531
# -- Generation 76 --
# Start of evolution
#   Evaluated 400 individuals
# -- Generation 1 --
#   Evaluated 378 individuals
#   Min 65.0
#   Max 94.0
#   Avg 79.43
#   Std 4.824427427166765
# -- Generation 2 --
#   Evaluated 391 individuals
#   Min 63.0
#   Max 91.0
#   Avg 76.5825
#   Std 4.540175519735036
# -- Generation 3 --
#   Evaluated 378 individuals
#   Min 62.0
#   Max 89.0
#   Avg 74.6025
#   Std 4.668992798238158
# -- Generation 4 --
#   Evaluated 382 individuals
#   Min 60.0
#   Max 87.0
#   Avg 73.5675
#   Std 4.601678362293517
# -- Generation 5 --
#   Evaluated 386 individuals
#   Min 58.0
#   Max 86.0
#   Avg 71.6975
#   Std 4.448706975065886
# -- Generation 6 --
#   Evaluated 383 individuals
#   Min 56.0
#   Max 82.0
#   Avg 70.535
#   Std 4.193897352105815
# -- Generation 7 --
#   Evaluated 387 individuals
#   Min 58.0
#   Max 85.0
#   Avg 69.78
#   Std 4.492950033107424
# -- Generation 8 --
#   Evaluated 378 individuals
#   Min 57.0
#   Max 80.0
#   Avg 68.38
#   Std 4.426126975133051
# -- Generation 9 --
#   Evaluated 385 individuals
#   Min 57.0
#   Max 80.0
#   Avg 67.385
#   Std 4.239902711147884
# -- Generation 10 --
#   Evaluated 381 individuals
#   Min 56.0
#   Max 82.0
#   Avg 66.205
#   Std 4.289286071131169
# -- Generation 11 --
#   Evaluated 391 individuals
#   Min 52.0
#   Max 82.0
#   Avg 65.39
#   Std 4.671498688857797
# -- Generation 12 --
#   Evaluated 381 individuals
#   Min 49.0
#   Max 83.0
#   Avg 64.5925
#   Std 5.17121298633117
# -- Generation 13 --
#   Evaluated 380 individuals
#   Min 51.0
#   Max 79.0
#   Avg 63.3375
#   Std 4.9908510045883325
# -- Generation 14 --
#   Evaluated 377 individuals
#   Min 51.0
#   Max 77.0
#   Avg 62.24
#   Std 4.678397161421806
# -- Generation 15 --
#   Evaluated 387 individuals
#   Min 50.0
#   Max 75.0
#   Avg 61.4975
#   Std 4.472135256228249
# -- Generation 16 --
#   Evaluated 384 individuals
#   Min 49.0
#   Max 75.0
#   Avg 60.5025
#   Std 4.661007804112811
# -- Generation 17 --
#   Evaluated 380 individuals
#   Min 46.0
#   Max 76.0
#   Avg 59.07
#   Std 4.553031956839285
# -- Generation 18 --
#   Evaluated 388 individuals
#   Min 46.0
#   Max 70.0
#   Avg 57.38
#   Std 4.189343624005982
# -- Generation 19 --
#   Evaluated 384 individuals
#   Min 47.0
#   Max 68.0
#   Avg 56.0775
#   Std 4.0064315481485755
# -- Generation 20 --
#   Evaluated 383 individuals
#   Min 45.0
#   Max 82.0
#   Avg 55.035
#   Std 4.450143256121175
# -- Generation 21 --
#   Evaluated 382 individuals
#   Min 43.0
#   Max 88.0
#   Avg 53.7275
#   Std 4.4151153722184535
# -- Generation 22 --
#   Evaluated 388 individuals
#   Min 41.0
#   Max 71.0
#   Avg 52.49
#   Std 4.269063129071783
# -- Generation 23 --
#   Evaluated 384 individuals
#   Min 42.0
#   Max 87.0
#   Avg 51.1875
#   Std 4.2062267829968425
# -- Generation 24 --
#   Evaluated 385 individuals
#   Min 41.0
#   Max 85.0
#   Avg 50.53
#   Std 5.603936116695099
# -- Generation 25 --
#   Evaluated 387 individuals
#   Min 40.0
#   Max 95.0
#   Avg 49.68
#   Std 5.87772064664529
# -- Generation 26 --
#   Evaluated 389 individuals
#   Min 38.0
#   Max 87.0
#   Avg 48.6225
#   Std 6.25739512497009
# -- Generation 27 --
#   Evaluated 380 individuals
#   Min 38.0
#   Max 84.0
#   Avg 47.1
#   Std 5.116150896914567
# -- Generation 28 --
#   Evaluated 385 individuals
#   Min 37.0
#   Max 87.0
#   Avg 46.65
#   Std 7.7102204897136515
# -- Generation 29 --
#   Evaluated 381 individuals
#   Min 36.0
#   Max 90.0
#   Avg 45.1975
#   Std 7.531832031451584
# -- Generation 30 --
#   Evaluated 382 individuals
#   Min 34.0
#   Max 91.0
#   Avg 44.345
#   Std 7.842893279906347
# -- Generation 31 --
#   Evaluated 384 individuals
#   Min 34.0
#   Max 91.0
#   Avg 43.47
#   Std 7.641276071442524
# -- Generation 32 --
#   Evaluated 385 individuals
#   Min 30.0
#   Max 87.0
#   Avg 42.5375
#   Std 7.261789982504295
# -- Generation 33 --
#   Evaluated 382 individuals
#   Min 31.0
#   Max 87.0
#   Avg 41.505
#   Std 7.182616166829456
# -- Generation 34 --
#   Evaluated 390 individuals
#   Min 31.0
#   Max 99.0
#   Avg 41.13
#   Std 8.678023968623258
# -- Generation 35 --
#   Evaluated 382 individuals
#   Min 29.0
#   Max 83.0
#   Avg 39.1975
#   Std 5.494405677596089
# -- Generation 36 --
#   Evaluated 380 individuals
#   Min 28.0
#   Max 85.0
#   Avg 38.34
#   Std 7.528904302752152
# -- Generation 37 --
#   Evaluated 378 individuals
#   Min 29.0
#   Max 83.0
#   Avg 37.055
#   Std 6.230728288089609
# -- Generation 38 --
#   Evaluated 386 individuals
#   Min 28.0
#   Max 84.0
#   Avg 36.705
#   Std 7.801793063136199
# -- Generation 39 --
#   Evaluated 381 individuals
#   Min 27.0
#   Max 84.0
#   Avg 35.5175
#   Std 6.839202713036081
# -- Generation 40 --
#   Evaluated 388 individuals
#   Min 27.0
#   Max 84.0
#   Avg 34.5
#   Std 5.454814387309628
# -- Generation 41 --
#   Evaluated 389 individuals
#   Min 26.0
#   Max 90.0
#   Avg 33.98
#   Std 6.434252093289491
# -- Generation 42 --
#   Evaluated 387 individuals
#   Min 24.0
#   Max 86.0
#   Avg 33.06
#   Std 4.816264112359292
# -- Generation 43 --
#   Evaluated 391 individuals
#   Min 24.0
#   Max 86.0
#   Avg 32.5225
#   Std 5.131714503945037
# -- Generation 44 --
#   Evaluated 376 individuals
#   Min 24.0
#   Max 78.0
#   Avg 31.6125
#   Std 3.7359528570366023
# -- Generation 45 --
#   Evaluated 387 individuals
#   Min 24.0
#   Max 78.0
#   Avg 31.1375
#   Std 3.6067428172798857
# -- Generation 46 --
#   Evaluated 380 individuals
#   Min 23.0
#   Max 85.0
#   Avg 30.6825
#   Std 4.4968537612424075
# -- Generation 47 --
#   Evaluated 384 individuals
#   Min 23.0
#   Max 40.0
#   Avg 29.9125
#   Std 2.637203774834227
# -- Generation 48 --
#   Evaluated 388 individuals
#   Min 23.0
#   Max 82.0
#   Avg 29.645
#   Std 3.7919618932684545
# -- Generation 49 --
#   Evaluated 383 individuals
#   Min 21.0
#   Max 79.0
#   Avg 28.98
#   Std 3.7622599591203105
# -- Generation 50 --
#   Evaluated 389 individuals
#   Min 21.0
#   Max 91.0
#   Avg 28.79
#   Std 5.6436601598608
# -- Generation 51 --
#   Evaluated 384 individuals
#   Min 20.0
#   Max 76.0
#   Avg 28.2025
#   Std 4.396759460102398
# -- Generation 52 --
#   Evaluated 385 individuals
#   Min 19.0
#   Max 83.0
#   Avg 27.665
#   Std 4.832988206068794
# -- Generation 53 --
#   Evaluated 382 individuals
#   Min 15.0
#   Max 81.0
#   Avg 27.34
#   Std 5.570403935084062
# -- Generation 54 --
#   Evaluated 380 individuals
#   Min 17.0
#   Max 82.0
#   Avg 26.4725
#   Std 6.009512771431642
# -- Generation 55 --
#   Evaluated 380 individuals
#   Min 16.0
#   Max 80.0
#   Avg 25.775
#   Std 6.529883230196393
# -- Generation 56 --
#   Evaluated 386 individuals
#   Min 16.0
#   Max 91.0
#   Avg 25.7375
#   Std 8.849496807728668
# -- Generation 57 --
#   Evaluated 385 individuals
#   Min 16.0
#   Max 84.0
#   Avg 24.6675
#   Std 7.069083657023725
# -- Generation 58 --
#   Evaluated 378 individuals
#   Min 14.0
#   Max 89.0
#   Avg 23.725
#   Std 6.059651392613276
# -- Generation 59 --
#   Evaluated 378 individuals
#   Min 13.0
#   Max 82.0
#   Avg 23.015
#   Std 7.007123161469328
# -- Generation 60 --
#   Evaluated 375 individuals
#   Min 13.0
#   Max 83.0
#   Avg 22.985
#   Std 9.419117527666804
# -- Generation 61 --
#   Evaluated 384 individuals
#   Min 13.0
#   Max 84.0
#   Avg 22.7375
#   Std 10.304057149977382
# -- Generation 62 --
#   Evaluated 387 individuals
#   Min 12.0
#   Max 92.0
#   Avg 21.565
#   Std 10.736888515766568
# -- Generation 63 --
#   Evaluated 377 individuals
#   Min 12.0
#   Max 87.0
#   Avg 21.4225
#   Std 11.639973958304203
# -- Generation 64 --
#   Evaluated 387 individuals
#   Min 11.0
#   Max 82.0
#   Avg 21.045
#   Std 11.605945674523898
# -- Generation 65 --
#   Evaluated 387 individuals
#   Min 12.0
#   Max 89.0
#   Avg 20.2825
#   Std 11.418524149381131
# -- Generation 66 --
#   Evaluated 387 individuals
#   Min 10.0
#   Max 97.0
#   Avg 20.8675
#   Std 13.460867124743489
# -- Generation 67 --
#   Evaluated 388 individuals
#   Min 10.0
#   Max 85.0
#   Avg 19.52
#   Std 11.388134175535518
# -- Generation 68 --
#   Evaluated 379 individuals
#   Min 10.0
#   Max 82.0
#   Avg 19.4
#   Std 12.418534535121287
# -- Generation 69 --
#   Evaluated 375 individuals
#   Min 10.0
#   Max 84.0
#   Avg 20.02
#   Std 13.847909589537336
# -- Generation 70 --
#   Evaluated 387 individuals
#   Min 10.0
#   Max 82.0
#   Avg 17.865
#   Std 11.043630517180482
# -- Generation 71 --
#   Evaluated 386 individuals
#   Min 9.0
#   Max 81.0
#   Avg 17.6575
#   Std 11.576061236448261
# -- Generation 72 --
#   Evaluated 387 individuals
#   Min 9.0
#   Max 87.0
#   Avg 17.235
#   Std 12.207570397093765
# -- Generation 73 --
#   Evaluated 385 individuals
#   Min 9.0
#   Max 89.0
#   Avg 17.2575
#   Std 12.115947909676732
# -- Generation 74 --
#   Evaluated 379 individuals
#   Min 8.0
#   Max 84.0
#   Avg 16.3825
#   Std 10.424787467857557
# -- Generation 75 --
#   Evaluated 386 individuals
#   Min 8.0
#   Max 83.0
#   Avg 15.5175
#   Std 9.55220884141464
# -- Generation 76 --
#   Evaluated 382 individuals
#   Min 8.0
#   Max 76.0
#   Avg 14.3075
#   Std 6.5884705167436275
# -- Generation 77 --
#   Evaluated 382 individuals
#   Min 8.0
#   Max 85.0
#   Avg 14.3875
#   Std 7.726082043959928
# -- Generation 78 --
#   Evaluated 383 individuals
#   Min 7.0
#   Max 84.0
#   Avg 14.2375
#   Std 7.2609292621537085
# -- Generation 79 --
#   Evaluated 390 individuals
#   Min 7.0
#   Max 62.0
#   Avg 13.1975
#   Std 3.3975717431718806
# -- Generation 80 --
#   Evaluated 378 individuals
#   Min 7.0
#   Max 82.0
#   Avg 12.61
#   Std 4.128910267855192
# -- Generation 81 --
#   Evaluated 378 individuals
#   Min 6.0
#   Max 49.0
#   Avg 12.165
#   Std 2.961042890604597
# -- Generation 82 --
#   Evaluated 384 individuals
#   Min 6.0
#   Max 91.0
#   Avg 12.2025
#   Std 5.252284621952621
# -- Generation 83 --
#   Evaluated 382 individuals
#   Min 6.0
#   Max 58.0
#   Avg 11.77
#   Std 3.340224543350344
# -- Generation 84 --
#   Evaluated 382 individuals
#   Min 6.0
#   Max 16.0
#   Avg 10.9975
#   Std 2.1430104409451647
# -- Generation 85 --
#   Evaluated 383 individuals
#   Min 6.0
#   Max 18.0
#   Avg 10.76
#   Std 2.192578390844898
# -- Generation 86 --
#   Evaluated 379 individuals
#   Min 6.0
#   Max 19.0
#   Avg 10.525
#   Std 2.2043990110685496
# -- Generation 87 --
#   Evaluated 379 individuals
#   Min 4.0
#   Max 17.0
#   Avg 10.215
#   Std 2.1791684193746925
# -- Generation 88 --
#   Evaluated 387 individuals
#   Min 5.0
#   Max 18.0
#   Avg 10.0325
#   Std 2.327325449953226
# -- Generation 89 --
#   Evaluated 393 individuals
#   Min 5.0
#   Max 20.0
#   Avg 9.645
#   Std 2.212233034741144
# -- Generation 90 --
#   Evaluated 376 individuals
#   Min 5.0
#   Max 17.0
#   Avg 9.295
#   Std 2.046454250649155
# -- Generation 91 --
#   Evaluated 383 individuals
#   Min 4.0
#   Max 16.0
#   Avg 9.0525
#   Std 2.163271538665454
# -- Generation 92 --
#   Evaluated 385 individuals
#   Min 4.0
#   Max 15.0
#   Avg 8.6875
#   Std 2.073606459770029
# -- Generation 93 --
#   Evaluated 382 individuals
#   Min 4.0
#   Max 58.0
#   Avg 8.4125
#   Std 3.1610668689542147
# -- Generation 94 --
#   Evaluated 389 individuals
#   Min 4.0
#   Max 90.0
#   Avg 8.0775
#   Std 4.4895983951796845
# -- Generation 95 --
#   Evaluated 380 individuals
#   Min 4.0
#   Max 13.0
#   Avg 7.78
#   Std 1.7865049678072529
# -- Generation 96 --
#   Evaluated 390 individuals
#   Min 4.0
#   Max 16.0
#   Avg 7.7925
#   Std 1.8081603219847497
# -- Generation 97 --
#   Evaluated 381 individuals
#   Min 4.0
#   Max 13.0
#   Avg 7.72
#   Std 1.8266362527881692
# -- Generation 98 --
#   Evaluated 388 individuals
#   Min 4.0
#   Max 16.0
#   Avg 7.705
#   Std 1.9060364634497426
# -- Generation 99 --
#   Evaluated 386 individuals
#   Min 2.0
#   Max 13.0
#   Avg 7.4375
#   Std 1.9470731239478403
# -- Generation 100 --
#   Evaluated 379 individuals
#   Min 2.0
#   Max 35.0
#   Avg 7.1575
#   Std 2.3532304923232665
# -- Generation 101 --
#   Evaluated 376 individuals
#   Min 2.0
#   Max 48.0
#   Avg 6.995
#   Std 2.741345472573641
# -- Generation 102 --
#   Evaluated 378 individuals
#   Min 2.0
#   Max 12.0
#   Avg 6.8525
#   Std 1.8616508131225902
# -- Generation 103 --
#   Evaluated 385 individuals
#   Min 2.0
#   Max 61.0
#   Avg 6.95
#   Std 3.3499999999999996
# -- Generation 104 --
#   Evaluated 379 individuals
#   Min 2.0
#   Max 87.0
#   Avg 6.8375
#   Std 4.466664723258283
# -- Generation 105 --
#   Evaluated 380 individuals
#   Min 2.0
#   Max 76.0
#   Avg 7.045
#   Std 5.654907161041638
# -- Generation 106 --
#   Evaluated 382 individuals
#   Min 2.0
#   Max 75.0
#   Avg 6.7875
#   Std 4.907885873774981
# -- Generation 107 --
#   Evaluated 388 individuals
#   Min 2.0
#   Max 14.0
#   Avg 6.3925
#   Std 2.0021098246599753
# -- Generation 108 --
#   Evaluated 381 individuals
#   Min 2.0
#   Max 13.0
#   Avg 6.3425
#   Std 2.0187109129342904
# -- Generation 109 --
#   Evaluated 383 individuals
#   Min 0.0
#   Max 90.0
#   Avg 6.375
#   Std 5.420735651182412
#
#
# SOLUCIÓN en la generación 109
# 8 4 2 | 7 1 9 | 3 5 6
# 7 9 3 | 6 4 5 | 1 8 2
# 6 5 1 | 3 8 2 | 9 4 7
# ----- + ----- + -----
# 9 8 7 | 2 3 1 | 5 6 4
# 3 1 5 | 8 6 4 | 2 7 9
# 2 6 4 | 5 9 7 | 8 3 1
# ----- + ----- + -----
# 4 7 9 | 1 5 8 | 6 2 3
# 5 2 6 | 9 7 3 | 4 1 8
# 1 3 8 | 4 2 6 | 7 9 5
# Fitness: 0.0
# CPU times: user 23.3 s, sys: 147 ms, total: 23.5 s
# Wall time: 23.4 s

# %%
grafica(estadisticas)
